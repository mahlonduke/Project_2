# %% [markdown]
# # ATOMM API

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import pprint as pp

# %%
baseURL = 'https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?pagesize=100&radius=50&latitude='
lat = '30.276930'
lon = '-97.743102'
apiKey = '35fd2afa0b109b9387bbf24e55f321b9'
queryURL = baseURL + lat + '&longitude=' + lon
#queryURL = 'https://api.gateway.attomdata.com/propertyapi/v1.0.0/sale/snapshot?pagesize=100&radius=50&latitude=30.276930&longitude=-97.743102'
# Headers for the request
headers = {
'Accept': 'application/json',
'APIKey': apiKey
}
response = requests.get(queryURL, headers=headers)
print("Complete")
# Out:
# Complete

# %%
pp.pprint(response.json())
# Out:
# {'property': [{'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '110 DOMINO FIVE',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '110 DOMINO FIVE, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '8112',
#                            'postal3': 'R001'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 1296}},
#                'identifier': {'apn': '000000050423',
#                               'apnOrig': '50423',
#                               'attomId': 47511783,
#                               'fips': '48187',
#                               'obPropId': 4751178348187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.82,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4892793, DB4839690, '
#                                      'RS0000557450, SB0000123986, '
#                                      'SB0000123989, SB0000123993, '
#                                      'SB0000123995, ZI78155',
#                             'latitude': '29.554490',
#                             'longitude': '-97.784540'},
#                'lot': {'lotSize1': 1.0},
#                'sale': {'amount': {'saleamt': 94627,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000011103',
#                                    'salerecdate': '2017-5-18',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 73},
#                         'saleTransDate': '2017-5-15',
#                         'salesearchdate': '2017-5-15'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'MOBILE HOME',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'MOBILE HOME',
#                            'proptype': 'MOBILE HOME',
#                            'yearbuilt': 2009},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '9835 ALTERNATE 90',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '9835 ALTERNATE 90, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '9109',
#                            'postal3': 'R001'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 0}},
#                'identifier': {'apn': '000000062633',
#                               'apnOrig': '62633',
#                               'attomId': 167987237,
#                               'fips': '48187',
#                               'obPropId': 16798723748187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.36,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4892793, DB4839690, '
#                                      'SB0000123986, SB0000123989, '
#                                      'SB0000123993, SB0000123995, ZI78155',
#                             'latitude': '29.562647',
#                             'longitude': '-97.810311'},
#                'lot': {'lotSize1': 49.674},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000002858',
#                                    'salerecdate': '2009-1-26',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2009-1-26',
#                         'salesearchdate': '2009-1-26'},
#                'summary': {'propIndicator': '80',
#                            'propLandUse': 'AGRICULTURAL (NEC)',
#                            'propclass': 'Vacant',
#                            'propsubtype': 'RESIDENTIAL',
#                            'proptype': 'AGRICULTURAL (NEC)',
#                            'yearbuilt': 0},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '5513 ALTERNATE 90',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '5513 ALTERNATE 90, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '1635',
#                            'postal3': 'R005'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 2400}},
#                'identifier': {'apn': '000000114371',
#                               'apnOrig': '114371',
#                               'attomId': 167995227,
#                               'fips': '48187',
#                               'obPropId': 16799522748187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.85,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'SB0000123986, SB0000123989, '
#                                      'SB0000123993, SB0000123995, ZI78155',
#                             'latitude': '29.563076',
#                             'longitude': '-97.880323'},
#                'lot': {'lotSize1': 0.99},
#                'sale': {'amount': {'saleamt': 145000,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000007680',
#                                    'salerecdate': '2014-5-8',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 60},
#                         'saleTransDate': '2014-5-6',
#                         'salesearchdate': '2014-5-6'},
#                'summary': {'propIndicator': '20',
#                            'propLandUse': 'COMMON AREA',
#                            'propclass': 'Commercial',
#                            'propsubtype': 'COMMERCIAL',
#                            'proptype': 'COMMON AREA',
#                            'yearbuilt': 2004},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '160 CASTLEWOOD DR',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '160 CASTLEWOOD DR, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '8102',
#                            'postal3': 'R005'},
#                'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                             'size': {'universalsize': 1927}},
#                'identifier': {'apn': '000000018049',
#                               'apnOrig': '18049',
#                               'attomId': 34563354,
#                               'fips': '48187',
#                               'obPropId': 3456335448187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.32,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, RS0000555064, '
#                                      'ZI78155',
#                             'latitude': '29.570888',
#                             'longitude': '-97.880241'},
#                'lot': {'lotSize1': 0.5},
#                'sale': {'amount': {'saleamt': 253125,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000003767',
#                                    'salerecdate': '2017-2-17',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 84375,
#                                         'pricepersizeunit': 131},
#                         'saleTransDate': '2017-2-15',
#                         'salesearchdate': '2017-2-15'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1999},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1125 FM 2438',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1125 FM 2438, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '8770',
#                            'postal3': 'R005'},
#                'building': {'rooms': {'bathstotal': 6.0, 'beds': 0},
#                             'size': {'universalsize': 8542}},
#                'identifier': {'apn': '000000109792',
#                               'apnOrig': '109792',
#                               'attomId': 165555281,
#                               'fips': '48187',
#                               'obPropId': 16555528148187},
#                'location': {'accuracy': 'Street',
#                             'distance': 48.75,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, ZI78155',
#                             'latitude': '29.574483',
#                             'longitude': '-97.842739'},
#                'lot': {'lotSize1': 3.0},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000016017',
#                                    'salerecdate': '2006-7-19',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2006-7-19',
#                         'salesearchdate': '2006-7-19'},
#                'summary': {'propIndicator': '70',
#                            'propLandUse': 'FARMS',
#                            'propclass': 'Agricultural',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'FARMS',
#                            'yearbuilt': 2003},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '187 TOWNESEND RD',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '187 TOWNESEND RD, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '4032',
#                            'postal3': 'C002'},
#                'building': {'rooms': {'bathstotal': 3.0, 'beds': 3},
#                             'size': {'universalsize': 1559}},
#                'identifier': {'apn': '000000044281',
#                               'apnOrig': '44281',
#                               'attomId': 167357531,
#                               'fips': '48187',
#                               'obPropId': 16735753148187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.74,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, RS0000530922, SB0000123986, '
#                                      'SB0000123989, SB0000123992, '
#                                      'SB0000123993, ZI78155',
#                             'latitude': '29.575333',
#                             'longitude': '-97.939118'},
#                'lot': {'lotSize1': 0.2248},
#                'sale': {'amount': {'saleamt': 182000,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000022928',
#                                    'salerecdate': '2017-9-25',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 60667,
#                                         'pricepersizeunit': 117},
#                         'saleTransDate': '2017-9-22',
#                         'salesearchdate': '2017-9-22'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1978},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '917 E HUMPHREYS ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '917 E HUMPHREYS ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '4616',
#                            'postal3': 'C014'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 2055}},
#                'identifier': {'apn': '000000016471',
#                               'apnOrig': '16471',
#                               'attomId': 166907779,
#                               'fips': '48187',
#                               'obPropId': 16690777948187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.88,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                             'latitude': '29.576655',
#                             'longitude': '-97.954726'},
#                'lot': {'lotSize1': 0.1645},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000000254',
#                                    'salerecdate': '2013-1-3',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2013-1-3',
#                         'salesearchdate': '2013-1-3'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1972},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '712 E NEW BRAUNFELS ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '712 E NEW BRAUNFELS ST, SEGUIN, TX '
#                                       '78155',
#                            'postal1': '78155',
#                            'postal2': '2835',
#                            'postal3': 'C006'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 1040}},
#                'identifier': {'apn': '000000022368',
#                               'apnOrig': '22368',
#                               'attomId': 164881022,
#                               'fips': '48187',
#                               'obPropId': 16488102248187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.49,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123989, '
#                                      'SB0000123991, SB0000123993, ZI78155',
#                             'latitude': '29.583241',
#                             'longitude': '-97.957761'},
#                'lot': {'lotSize1': 0.165},
#                'sale': {'amount': {'saleamt': 183015,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000024388',
#                                    'salerecdate': '2017-10-16',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 176},
#                         'saleTransDate': '2017-10-13',
#                         'salesearchdate': '2017-10-13'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 2000},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1340 E KINGSBURY ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1340 E KINGSBURY ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '4048',
#                            'postal3': 'C006'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 20730}},
#                'identifier': {'apn': '000000059510',
#                               'apnOrig': '59510',
#                               'attomId': 167364444,
#                               'fips': '48187',
#                               'obPropId': 16736444448187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.23,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123989, '
#                                      'SB0000123992, SB0000123993, ZI78155',
#                             'latitude': '29.584475',
#                             'longitude': '-97.946453'},
#                'lot': {'lotSize1': 1.32},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000013413',
#                                    'salerecdate': '2012-7-18',
#                                    'saletranstype': 'Nominal - Non/Arms Length '
#                                                     'Sale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2012-7-10',
#                         'salesearchdate': '2012-7-10'},
#                'summary': {'propIndicator': '20',
#                            'propLandUse': 'COMMON AREA',
#                            'propclass': 'Commercial',
#                            'propsubtype': 'COMMERCIAL',
#                            'proptype': 'COMMON AREA',
#                            'yearbuilt': 2000},
#                'vintage': {'lastModified': '2018-1-27',
#                            'pubDate': '2018-1-27'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '367 SHOSHONI',
#                            'line2': 'KINGSBURY, TX 78638',
#                            'locality': 'Kingsbury',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '367 SHOSHONI, KINGSBURY, TX 78638',
#                            'postal1': '78638',
#                            'postal2': '3116',
#                            'postal3': 'R302'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 1904}},
#                'identifier': {'apn': '000000027855',
#                               'apnOrig': '27855',
#                               'attomId': 167349719,
#                               'fips': '48187',
#                               'obPropId': 16734971948187},
#                'location': {'accuracy': 'Street',
#                             'distance': 48.1,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4892793, DB4839690, '
#                                      'SB0000123986, SB0000123989, '
#                                      'SB0000123993, SB0000123995, ZI78638',
#                             'latitude': '29.578655',
#                             'longitude': '-97.730188'},
#                'lot': {'lotSize1': 10.19},
#                'sale': {'amount': {'saleamt': 70000,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000002086',
#                                    'salerecdate': '2015-2-3',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 37},
#                         'saleTransDate': '2015-1-30',
#                         'salesearchdate': '2015-1-30'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1900},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1126 BARTHOLOMAE ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1126 BARTHOLOMAE ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '3706',
#                            'postal3': 'C005'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 0}},
#                'identifier': {'apn': '000000015209',
#                               'apnOrig': '15209',
#                               'attomId': 164874096,
#                               'fips': '48187',
#                               'obPropId': 16487409648187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.81,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123988, '
#                                      'SB0000123989, SB0000123993, ZI78155',
#                             'latitude': '29.579328',
#                             'longitude': '-97.961491'},
#                'lot': {'lotSize1': 0.3603},
#                'sale': {'amount': {'saleamt': 159556,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000016742',
#                                    'salerecdate': '2018-7-26',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2018-7-20',
#                         'salesearchdate': '2018-7-20'},
#                'summary': {'propIndicator': '90',
#                            'propLandUse': 'PUBLIC (NEC)',
#                            'propclass': 'Exempt',
#                            'propsubtype': 'RESIDENTIAL',
#                            'proptype': 'PUBLIC (NEC)',
#                            'yearbuilt': 0},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1139 CREEKSIDE POND RD',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1139 CREEKSIDE POND RD, SEGUIN, TX '
#                                       '78155',
#                            'postal1': '78155',
#                            'postal2': '2401',
#                            'postal3': 'C002'},
#                'building': {'rooms': {'bathstotal': 3.0, 'beds': 3},
#                             'size': {'universalsize': 2400}},
#                'identifier': {'apn': '000000134142',
#                               'apnOrig': '134142',
#                               'attomId': 246566484,
#                               'fips': '48187',
#                               'obPropId': 24656648448187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.33,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, PL4866644, '
#                                      'RS0004488207, ZI78155',
#                             'latitude': '29.579545',
#                             'longitude': '-97.930573'},
#                'lot': {'lotSize1': 0.3037},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000023606',
#                                    'salerecdate': '2016-10-24',
#                                    'saletranstype': 'New Construction'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2016-10-21',
#                         'salesearchdate': '2016-10-21'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 2016},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1142 MAGNOLIA',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1142 MAGNOLIA, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '2162',
#                            'postal3': 'C006'},
#                'building': {'rooms': {'bathstotal': 1.0, 'beds': 4},
#                             'size': {'universalsize': 1248}},
#                'identifier': {'apn': '000000021377',
#                               'apnOrig': '21377',
#                               'attomId': 165546307,
#                               'fips': '48187',
#                               'obPropId': 16554630748187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.09,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, RS0000008108, SB0000123986, '
#                                      'SB0000123989, SB0000123991, '
#                                      'SB0000123993, ZI78155',
#                             'latitude': '29.586841',
#                             'longitude': '-97.947836'},
#                'lot': {'lotSize1': 0.19},
#                'sale': {'amount': {'saleamt': 62500,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000023886',
#                                    'salerecdate': '2015-11-23',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 15625,
#                                         'pricepersizeunit': 50},
#                         'saleTransDate': '2015-11-16',
#                         'salesearchdate': '2015-11-16'},
#                'summary': {'propIndicator': '21',
#                            'propLandUse': 'DUPLEX',
#                            'propclass': '"Duplex, Triplex, Quadplex)"',
#                            'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#                            'proptype': 'DUPLEX',
#                            'yearbuilt': 1983},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1216 WINDY DAWN',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1216 WINDY DAWN, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '4113',
#                            'postal3': 'C002'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 2154}},
#                'identifier': {'apn': '000000134130',
#                               'apnOrig': '134130',
#                               'attomId': 246566474,
#                               'fips': '48187',
#                               'obPropId': 24656647448187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.31,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, RS0004488207, SB0000123986, '
#                                      'SB0000123989, SB0000123992, '
#                                      'SB0000123993, ZI78155',
#                             'latitude': '29.579720',
#                             'longitude': '-97.929629'},
#                'lot': {'lotSize1': 0.2871},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000013731',
#                                    'salerecdate': '2014-8-8',
#                                    'saletranstype': 'New Construction'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2014-7-31',
#                         'salesearchdate': '2014-7-31'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 2014},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '708 E WEINERT ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '708 E WEINERT ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '3836',
#                            'postal3': 'C006'},
#                'building': {'rooms': {'bathstotal': 1.0, 'beds': 0},
#                             'size': {'universalsize': 1442}},
#                'identifier': {'apn': '000000017021',
#                               'apnOrig': '17021',
#                               'attomId': 167344132,
#                               'fips': '48187',
#                               'obPropId': 16734413248187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.7,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                             'latitude': '29.580135',
#                             'longitude': '-97.958018'},
#                'lot': {'lotSize1': 0.5687},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000012167',
#                                    'salerecdate': '2008-6-25',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2008-6-25',
#                         'salesearchdate': '2008-6-25'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1951},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1710 N CAMP ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaZip',
#                            'oneLine': '1710 N CAMP ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '2020',
#                            'postal3': 'C017'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 0}},
#                'identifier': {'apn': '000000036112',
#                               'apnOrig': '36112',
#                               'attomId': 33755868,
#                               'fips': '48187',
#                               'obPropId': 3375586848187},
#                'location': {'accuracy': 'Zip9',
#                             'distance': 49.33,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123989, '
#                                      'SB0000123993, SB0000123996, ZI78155',
#                             'latitude': '29.587521',
#                             'longitude': '-97.965959'},
#                'lot': {'lotSize1': 0.1099},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000000661',
#                                    'salerecdate': '2008-1-10',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2007-6-22',
#                         'salesearchdate': '2007-6-22'},
#                'summary': {'propIndicator': '80',
#                            'propLandUse': 'RESIDENTIAL ACREAGE',
#                            'propclass': 'Vacant',
#                            'propsubtype': 'RESIDENTIAL',
#                            'proptype': 'RESIDENTIAL ACREAGE',
#                            'yearbuilt': 0},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1407 MOCKINGBIRD LN',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1407 MOCKINGBIRD LN, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '4016',
#                            'postal3': 'C006'},
#                'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                             'size': {'universalsize': 1566}},
#                'identifier': {'apn': '000000028633',
#                               'apnOrig': '28633',
#                               'attomId': 164888265,
#                               'fips': '48187',
#                               'obPropId': 16488826548187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.36,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, RS0001400806, SB0000123986, '
#                                      'SB0000123989, SB0000123992, '
#                                      'SB0000123993, ZI78155',
#                             'latitude': '29.581445',
#                             'longitude': '-97.941742'},
#                'lot': {'lotSize1': 0.2571},
#                'sale': {'amount': {'saleamt': 144375,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000023217',
#                                    'salerecdate': '2018-10-10',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 48125,
#                                         'pricepersizeunit': 92},
#                         'saleTransDate': '2018-10-5',
#                         'salesearchdate': '2018-10-5'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1974},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '932 ANDERSON ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '932 ANDERSON ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '2548',
#                            'postal3': 'C009'},
#                'building': {'rooms': {'bathstotal': 1.0, 'beds': 2},
#                             'size': {'universalsize': 912}},
#                'identifier': {'apn': '000000014072',
#                               'apnOrig': '14072',
#                               'attomId': 165216039,
#                               'fips': '48187',
#                               'obPropId': 16521603948187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.91,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123988, '
#                                      'SB0000123989, SB0000123994, '
#                                      'SB0000123996, ZI78155',
#                             'latitude': '29.581783',
#                             'longitude': '-97.977789'},
#                'lot': {'lotSize1': 0.1216},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000017628',
#                                    'salerecdate': '2010-10-14',
#                                    'saletranstype': 'Nominal - Non/Arms Length '
#                                                     'Sale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2010-9-13',
#                         'salesearchdate': '2010-9-13'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1950},
#                'vintage': {'lastModified': '2018-1-27',
#                            'pubDate': '2018-1-27'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '202 E PINE ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '202 E PINE ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '2642',
#                            'postal3': 'C017'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 1742}},
#                'identifier': {'apn': '000000046967',
#                               'apnOrig': '46967',
#                               'attomId': 2158882,
#                               'fips': '48187',
#                               'obPropId': 215888248187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.67,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                             'latitude': '29.582018',
#                             'longitude': '-97.963976'},
#                'lot': {'lotSize1': 0.2581},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000001038',
#                                    'salerecdate': '2009-11-19',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2009-11-19',
#                         'salesearchdate': '2009-11-19'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 1916},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '2115 LOUISE ST',
#                            'line2': 'SEGUIN, TX 78155',
#                            'locality': 'Seguin',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '2115 LOUISE ST, SEGUIN, TX 78155',
#                            'postal1': '78155',
#                            'postal2': '1949',
#                            'postal3': 'C017'},
#                'building': {'rooms': {'bathstotal': 1.0, 'beds': 2},
#                             'size': {'universalsize': 1312}},
#                'identifier': {'apn': '000000041024',
#                               'apnOrig': '41024',
#                               'attomId': 21499205,
#                               'fips': '48187',
#                               'obPropId': 2149920548187},
#                'location': {'accuracy': 'Street',
#                             'distance': 49.14,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4839690, '
#                                      'PL4866644, SB0000123986, SB0000123989, '
#                                      'SB0000123993, SB0000123996, ZI78155',
#                             'latitude': '29.590610',
#                             'longitude': '-97.966432'},
#                'lot': {'lotSize1': 0.1451},
#                'sale': {'amount': {'saleamt': 37500,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000005840',
#                                    'salerecdate': '2019-3-19',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 18750,
#                                         'pricepersizeunit': 29},
#                         'saleTransDate': '2019-3-13',
# ...
#                                    'saledocnum': '0000009641',
#                                    'salerecdate': '2008-5-22',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2008-5-20',
#                         'salesearchdate': '2008-5-20'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'MOBILE HOME',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'MOBILE HOME',
#                            'proptype': 'MOBILE HOME',
#                            'yearbuilt': 2004},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '2579 PAHMEYER RD',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '2579 PAHMEYER RD, NEW BRAUNFELS, TX '
#                                       '78130',
#                            'postal1': '78130',
#                            'postal2': '3933',
#                            'postal3': 'R044'},
#                'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                             'size': {'universalsize': 2738}},
#                'identifier': {'apn': '000000163694',
#                               'apnOrig': '163694',
#                               'attomId': 155233318,
#                               'fips': '48187',
#                               'obPropId': 15523331848187},
#                'location': {'accuracy': 'Street',
#                             'distance': 48.39,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893470, DB4832370, '
#                                      'MT30002734, PL4850820, RS0000409229, '
#                                      'SB0000122843, SB0000122844, '
#                                      'SB0000122850, SB0000136121, ZI78130',
#                             'latitude': '29.654160',
#                             'longitude': '-98.116624'},
#                'lot': {'lotSize1': 0.1942},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000004853',
#                                    'salerecdate': '2019-3-6',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2019-1-1',
#                         'salesearchdate': '2019-1-1'},
#                'summary': {'propIndicator': '21',
#                            'propLandUse': 'DUPLEX',
#                            'propclass': '"Duplex, Triplex, Quadplex)"',
#                            'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#                            'proptype': 'DUPLEX',
#                            'yearbuilt': 2017},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '191 MARUNGO LN',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '191 MARUNGO LN, NEW BRAUNFELS, TX 78130',
#                            'postal1': '78130',
#                            'postal2': '8265',
#                            'postal3': 'R030'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 4058}},
#                'identifier': {'apn': '000000128378',
#                               'apnOrig': '128378',
#                               'attomId': 165423690,
#                               'fips': '48187',
#                               'obPropId': 16542369048187},
#                'location': {'accuracy': 'Street',
#                             'distance': 47.31,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893470, DB4832370, '
#                                      'MT30002734, RS0000376033, SB0000122843, '
#                                      'SB0000122844, SB0000122850, '
#                                      'SB0000136121, ZI78130',
#                             'latitude': '29.654636',
#                             'longitude': '-98.076980'},
#                'lot': {'lotSize1': 1.84},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000005378',
#                                    'salerecdate': '2007-3-13',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2007-3-12',
#                         'salesearchdate': '2007-3-12'},
#                'summary': {'propIndicator': '21',
#                            'propLandUse': 'DUPLEX',
#                            'propclass': '"Duplex, Triplex, Quadplex)"',
#                            'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#                            'proptype': 'DUPLEX',
#                            'yearbuilt': 2007},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '1115 KRAUSE LN',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '1115 KRAUSE LN, NEW BRAUNFELS, TX 78130',
#                            'postal1': '78130',
#                            'postal2': '1908',
#                            'postal3': 'R032'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 924}},
#                'identifier': {'apn': '000000055410',
#                               'apnOrig': '55410',
#                               'attomId': 164909359,
#                               'fips': '48187',
#                               'obPropId': 16490935948187},
#                'location': {'accuracy': 'Street',
#                             'distance': 46.43,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893500, DB4814730, '
#                                      'SB0000119355, SB0000119356, '
#                                      'SB0000119372, ZI78130',
#                             'latitude': '29.655023',
#                             'longitude': '-98.041868'},
#                'lot': {'lotSize1': 2.0},
#                'sale': {'amount': {'saleamt': 0,
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000006998',
#                                    'salerecdate': '2012-4-13',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2012-4-13',
#                         'salesearchdate': '2012-4-13'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'MOBILE HOME',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'MOBILE HOME',
#                            'proptype': 'MOBILE HOME',
#                            'yearbuilt': 1982},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '115 RUGER PATH',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaStr',
#                            'oneLine': '115 RUGER PATH, NEW BRAUNFELS, TX 78130',
#                            'postal1': '78130',
#                            'postal2': '3959',
#                            'postal3': 'R028'},
#                'building': {'rooms': {'bathstotal': 4.0, 'beds': 4},
#                             'size': {'universalsize': 2844}},
#                'identifier': {'apn': '000000131372',
#                               'apnOrig': '131372',
#                               'attomId': 219318432,
#                               'fips': '48187',
#                               'obPropId': 21931843248187},
#                'location': {'accuracy': 'Street',
#                             'distance': 47.52,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893470, MT30002734, '
#                                      'PL4850820, RS0000096629, ZI78130',
#                             'latitude': '29.660535',
#                             'longitude': '-98.098821'},
#                'lot': {'lotSize1': 0.1515},
#                'sale': {'amount': {'saleamt': 221108,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000021428',
#                                    'salerecdate': '2013-10-2',
#                                    'saletranstype': 'New Construction'},
#                         'calculation': {'priceperbed': 55277,
#                                         'pricepersizeunit': 78},
#                         'saleTransDate': '2013-9-30',
#                         'salesearchdate': '2013-9-30'},
#                'summary': {'propIndicator': '10',
#                            'propLandUse': 'SFR',
#                            'propclass': 'Single Family Residence / Townhouse',
#                            'propsubtype': 'HOUSE',
#                            'proptype': 'SFR',
#                            'yearbuilt': 2013},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '328 RIVER PARK DR',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaZip',
#                            'oneLine': '328 RIVER PARK DR, NEW BRAUNFELS, TX '
#                                       '78130',
#                            'postal1': '78130',
#                            'postal2': '3569',
#                            'postal3': 'R037'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 0}},
#                'identifier': {'apn': '000000127630',
#                               'apnOrig': '127630',
#                               'attomId': 146063788,
#                               'fips': '48187',
#                               'obPropId': 14606378848187},
#                'location': {'accuracy': 'Zip9',
#                             'distance': 47.11,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893470, DB4832370, '
#                                      'MT30002734, SB0000122843, SB0000122844, '
#                                      'SB0000122850, SB0000136121, ZI78130',
#                             'latitude': '29.656185',
#                             'longitude': '-98.072729'},
#                'lot': {'lotSize1': 0.545},
#                'sale': {'amount': {'saleamt': 62500,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000011326',
#                                    'salerecdate': '2018-5-29',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2018-5-23',
#                         'salesearchdate': '2018-5-23'},
#                'summary': {'propIndicator': '80',
#                            'propLandUse': 'RESIDENTIAL ACREAGE',
#                            'propclass': 'Vacant',
#                            'propsubtype': 'RESIDENTIAL',
#                            'proptype': 'RESIDENTIAL ACREAGE',
#                            'yearbuilt': 0},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}},
#               {'address': {'country': 'US',
#                            'countrySubd': 'TX',
#                            'line1': '368 RIVER PARK DR',
#                            'line2': 'NEW BRAUNFELS, TX 78130',
#                            'locality': 'New Braunfels',
#                            'matchCode': 'ExaZip',
#                            'oneLine': '368 RIVER PARK DR, NEW BRAUNFELS, TX '
#                                       '78130',
#                            'postal1': '78130',
#                            'postal2': '3569',
#                            'postal3': 'R037'},
#                'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                             'size': {'universalsize': 0}},
#                'identifier': {'apn': '000000127635',
#                               'apnOrig': '127635',
#                               'attomId': 167700072,
#                               'fips': '48187',
#                               'obPropId': 16770007248187},
#                'location': {'accuracy': 'Zip9',
#                             'distance': 47.11,
#                             'elevation': 0.0,
#                             'geoid': 'CO48187, CS4893470, DB4832370, '
#                                      'MT30002734, SB0000122843, SB0000122844, '
#                                      'SB0000122850, SB0000136121, ZI78130',
#                             'latitude': '29.656185',
#                             'longitude': '-98.072729'},
#                'lot': {'lotSize1': 0.546},
#                'sale': {'amount': {'saleamt': 49000,
#                                    'salecode': 'Estimated Sale Price',
#                                    'saledisclosuretype': 2,
#                                    'saledocnum': '0000019196',
#                                    'salerecdate': '2014-10-30',
#                                    'saletranstype': 'Resale'},
#                         'calculation': {'priceperbed': 0,
#                                         'pricepersizeunit': 0},
#                         'saleTransDate': '2014-10-27',
#                         'salesearchdate': '2014-10-27'},
#                'summary': {'propIndicator': '80',
#                            'propLandUse': 'RESIDENTIAL ACREAGE',
#                            'propclass': 'Vacant',
#                            'propsubtype': 'RESIDENTIAL',
#                            'proptype': 'RESIDENTIAL ACREAGE',
#                            'yearbuilt': 0},
#                'vintage': {'lastModified': '2019-11-11',
#                            'pubDate': '2019-11-11'}}],
#  'status': {'code': 0,
#             'msg': 'SuccessWithResult',
#             'page': 1,
#             'pagesize': 100,
#             'total': 10000,
#             'version': '1.0.0'}}

# %%
cleanResponse = response.json()['property']
pp.pprint(cleanResponse)
# Out:
# [{'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '110 DOMINO FIVE',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '110 DOMINO FIVE, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '8112',
#               'postal3': 'R001'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 1296}},
#   'identifier': {'apn': '000000050423',
#                  'apnOrig': '50423',
#                  'attomId': 47511783,
#                  'fips': '48187',
#                  'obPropId': 4751178348187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.82,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4892793, DB4839690, RS0000557450, '
#                         'SB0000123986, SB0000123989, SB0000123993, '
#                         'SB0000123995, ZI78155',
#                'latitude': '29.554490',
#                'longitude': '-97.784540'},
#   'lot': {'lotSize1': 1.0},
#   'sale': {'amount': {'saleamt': 94627,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000011103',
#                       'salerecdate': '2017-5-18',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 73},
#            'saleTransDate': '2017-5-15',
#            'salesearchdate': '2017-5-15'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'MOBILE HOME',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'MOBILE HOME',
#               'proptype': 'MOBILE HOME',
#               'yearbuilt': 2009},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '9835 ALTERNATE 90',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '9835 ALTERNATE 90, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '9109',
#               'postal3': 'R001'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000062633',
#                  'apnOrig': '62633',
#                  'attomId': 167987237,
#                  'fips': '48187',
#                  'obPropId': 16798723748187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.36,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4892793, DB4839690, SB0000123986, '
#                         'SB0000123989, SB0000123993, SB0000123995, ZI78155',
#                'latitude': '29.562647',
#                'longitude': '-97.810311'},
#   'lot': {'lotSize1': 49.674},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000002858',
#                       'salerecdate': '2009-1-26',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2009-1-26',
#            'salesearchdate': '2009-1-26'},
#   'summary': {'propIndicator': '80',
#               'propLandUse': 'AGRICULTURAL (NEC)',
#               'propclass': 'Vacant',
#               'propsubtype': 'RESIDENTIAL',
#               'proptype': 'AGRICULTURAL (NEC)',
#               'yearbuilt': 0},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '5513 ALTERNATE 90',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '5513 ALTERNATE 90, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1635',
#               'postal3': 'R005'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 2400}},
#   'identifier': {'apn': '000000114371',
#                  'apnOrig': '114371',
#                  'attomId': 167995227,
#                  'fips': '48187',
#                  'obPropId': 16799522748187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.85,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, SB0000123986, '
#                         'SB0000123989, SB0000123993, SB0000123995, ZI78155',
#                'latitude': '29.563076',
#                'longitude': '-97.880323'},
#   'lot': {'lotSize1': 0.99},
#   'sale': {'amount': {'saleamt': 145000,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000007680',
#                       'salerecdate': '2014-5-8',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 60},
#            'saleTransDate': '2014-5-6',
#            'salesearchdate': '2014-5-6'},
#   'summary': {'propIndicator': '20',
#               'propLandUse': 'COMMON AREA',
#               'propclass': 'Commercial',
#               'propsubtype': 'COMMERCIAL',
#               'proptype': 'COMMON AREA',
#               'yearbuilt': 2004},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '160 CASTLEWOOD DR',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '160 CASTLEWOOD DR, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '8102',
#               'postal3': 'R005'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 1927}},
#   'identifier': {'apn': '000000018049',
#                  'apnOrig': '18049',
#                  'attomId': 34563354,
#                  'fips': '48187',
#                  'obPropId': 3456335448187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.32,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, RS0000555064, ZI78155',
#                'latitude': '29.570888',
#                'longitude': '-97.880241'},
#   'lot': {'lotSize1': 0.5},
#   'sale': {'amount': {'saleamt': 253125,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000003767',
#                       'salerecdate': '2017-2-17',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 84375, 'pricepersizeunit': 131},
#            'saleTransDate': '2017-2-15',
#            'salesearchdate': '2017-2-15'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1999},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1125 FM 2438',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1125 FM 2438, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '8770',
#               'postal3': 'R005'},
#   'building': {'rooms': {'bathstotal': 6.0, 'beds': 0},
#                'size': {'universalsize': 8542}},
#   'identifier': {'apn': '000000109792',
#                  'apnOrig': '109792',
#                  'attomId': 165555281,
#                  'fips': '48187',
#                  'obPropId': 16555528148187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.75,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, ZI78155',
#                'latitude': '29.574483',
#                'longitude': '-97.842739'},
#   'lot': {'lotSize1': 3.0},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000016017',
#                       'salerecdate': '2006-7-19',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2006-7-19',
#            'salesearchdate': '2006-7-19'},
#   'summary': {'propIndicator': '70',
#               'propLandUse': 'FARMS',
#               'propclass': 'Agricultural',
#               'propsubtype': 'HOUSE',
#               'proptype': 'FARMS',
#               'yearbuilt': 2003},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '187 TOWNESEND RD',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '187 TOWNESEND RD, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '4032',
#               'postal3': 'C002'},
#   'building': {'rooms': {'bathstotal': 3.0, 'beds': 3},
#                'size': {'universalsize': 1559}},
#   'identifier': {'apn': '000000044281',
#                  'apnOrig': '44281',
#                  'attomId': 167357531,
#                  'fips': '48187',
#                  'obPropId': 16735753148187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.74,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'RS0000530922, SB0000123986, SB0000123989, '
#                         'SB0000123992, SB0000123993, ZI78155',
#                'latitude': '29.575333',
#                'longitude': '-97.939118'},
#   'lot': {'lotSize1': 0.2248},
#   'sale': {'amount': {'saleamt': 182000,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000022928',
#                       'salerecdate': '2017-9-25',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 60667, 'pricepersizeunit': 117},
#            'saleTransDate': '2017-9-22',
#            'salesearchdate': '2017-9-22'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1978},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '917 E HUMPHREYS ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '917 E HUMPHREYS ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '4616',
#               'postal3': 'C014'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 2055}},
#   'identifier': {'apn': '000000016471',
#                  'apnOrig': '16471',
#                  'attomId': 166907779,
#                  'fips': '48187',
#                  'obPropId': 16690777948187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.88,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                'latitude': '29.576655',
#                'longitude': '-97.954726'},
#   'lot': {'lotSize1': 0.1645},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000000254',
#                       'salerecdate': '2013-1-3',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2013-1-3',
#            'salesearchdate': '2013-1-3'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1972},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '712 E NEW BRAUNFELS ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '712 E NEW BRAUNFELS ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2835',
#               'postal3': 'C006'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 1040}},
#   'identifier': {'apn': '000000022368',
#                  'apnOrig': '22368',
#                  'attomId': 164881022,
#                  'fips': '48187',
#                  'obPropId': 16488102248187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.49,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123991, '
#                         'SB0000123993, ZI78155',
#                'latitude': '29.583241',
#                'longitude': '-97.957761'},
#   'lot': {'lotSize1': 0.165},
#   'sale': {'amount': {'saleamt': 183015,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000024388',
#                       'salerecdate': '2017-10-16',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 176},
#            'saleTransDate': '2017-10-13',
#            'salesearchdate': '2017-10-13'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2000},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1340 E KINGSBURY ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1340 E KINGSBURY ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '4048',
#               'postal3': 'C006'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 20730}},
#   'identifier': {'apn': '000000059510',
#                  'apnOrig': '59510',
#                  'attomId': 167364444,
#                  'fips': '48187',
#                  'obPropId': 16736444448187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.23,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123992, '
#                         'SB0000123993, ZI78155',
#                'latitude': '29.584475',
#                'longitude': '-97.946453'},
#   'lot': {'lotSize1': 1.32},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000013413',
#                       'salerecdate': '2012-7-18',
#                       'saletranstype': 'Nominal - Non/Arms Length Sale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2012-7-10',
#            'salesearchdate': '2012-7-10'},
#   'summary': {'propIndicator': '20',
#               'propLandUse': 'COMMON AREA',
#               'propclass': 'Commercial',
#               'propsubtype': 'COMMERCIAL',
#               'proptype': 'COMMON AREA',
#               'yearbuilt': 2000},
#   'vintage': {'lastModified': '2018-1-27', 'pubDate': '2018-1-27'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '367 SHOSHONI',
#               'line2': 'KINGSBURY, TX 78638',
#               'locality': 'Kingsbury',
#               'matchCode': 'ExaStr',
#               'oneLine': '367 SHOSHONI, KINGSBURY, TX 78638',
#               'postal1': '78638',
#               'postal2': '3116',
#               'postal3': 'R302'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 1904}},
#   'identifier': {'apn': '000000027855',
#                  'apnOrig': '27855',
#                  'attomId': 167349719,
#                  'fips': '48187',
#                  'obPropId': 16734971948187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.1,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4892793, DB4839690, SB0000123986, '
#                         'SB0000123989, SB0000123993, SB0000123995, ZI78638',
#                'latitude': '29.578655',
#                'longitude': '-97.730188'},
#   'lot': {'lotSize1': 10.19},
#   'sale': {'amount': {'saleamt': 70000,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000002086',
#                       'salerecdate': '2015-2-3',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 37},
#            'saleTransDate': '2015-1-30',
#            'salesearchdate': '2015-1-30'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1900},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1126 BARTHOLOMAE ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1126 BARTHOLOMAE ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '3706',
#               'postal3': 'C005'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000015209',
#                  'apnOrig': '15209',
#                  'attomId': 164874096,
#                  'fips': '48187',
#                  'obPropId': 16487409648187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.81,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123988, SB0000123989, '
#                         'SB0000123993, ZI78155',
#                'latitude': '29.579328',
#                'longitude': '-97.961491'},
#   'lot': {'lotSize1': 0.3603},
#   'sale': {'amount': {'saleamt': 159556,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000016742',
#                       'salerecdate': '2018-7-26',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2018-7-20',
#            'salesearchdate': '2018-7-20'},
#   'summary': {'propIndicator': '90',
#               'propLandUse': 'PUBLIC (NEC)',
#               'propclass': 'Exempt',
#               'propsubtype': 'RESIDENTIAL',
#               'proptype': 'PUBLIC (NEC)',
#               'yearbuilt': 0},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1139 CREEKSIDE POND RD',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1139 CREEKSIDE POND RD, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2401',
#               'postal3': 'C002'},
#   'building': {'rooms': {'bathstotal': 3.0, 'beds': 3},
#                'size': {'universalsize': 2400}},
#   'identifier': {'apn': '000000134142',
#                  'apnOrig': '134142',
#                  'attomId': 246566484,
#                  'fips': '48187',
#                  'obPropId': 24656648448187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.33,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, RS0004488207, ZI78155',
#                'latitude': '29.579545',
#                'longitude': '-97.930573'},
#   'lot': {'lotSize1': 0.3037},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000023606',
#                       'salerecdate': '2016-10-24',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2016-10-21',
#            'salesearchdate': '2016-10-21'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2016},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1142 MAGNOLIA',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1142 MAGNOLIA, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2162',
#               'postal3': 'C006'},
#   'building': {'rooms': {'bathstotal': 1.0, 'beds': 4},
#                'size': {'universalsize': 1248}},
#   'identifier': {'apn': '000000021377',
#                  'apnOrig': '21377',
#                  'attomId': 165546307,
#                  'fips': '48187',
#                  'obPropId': 16554630748187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.09,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'RS0000008108, SB0000123986, SB0000123989, '
#                         'SB0000123991, SB0000123993, ZI78155',
#                'latitude': '29.586841',
#                'longitude': '-97.947836'},
#   'lot': {'lotSize1': 0.19},
#   'sale': {'amount': {'saleamt': 62500,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000023886',
#                       'salerecdate': '2015-11-23',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 15625, 'pricepersizeunit': 50},
#            'saleTransDate': '2015-11-16',
#            'salesearchdate': '2015-11-16'},
#   'summary': {'propIndicator': '21',
#               'propLandUse': 'DUPLEX',
#               'propclass': '"Duplex, Triplex, Quadplex)"',
#               'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#               'proptype': 'DUPLEX',
#               'yearbuilt': 1983},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1216 WINDY DAWN',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1216 WINDY DAWN, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '4113',
#               'postal3': 'C002'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 2154}},
#   'identifier': {'apn': '000000134130',
#                  'apnOrig': '134130',
#                  'attomId': 246566474,
#                  'fips': '48187',
#                  'obPropId': 24656647448187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.31,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'RS0004488207, SB0000123986, SB0000123989, '
#                         'SB0000123992, SB0000123993, ZI78155',
#                'latitude': '29.579720',
#                'longitude': '-97.929629'},
#   'lot': {'lotSize1': 0.2871},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000013731',
#                       'salerecdate': '2014-8-8',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2014-7-31',
#            'salesearchdate': '2014-7-31'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2014},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '708 E WEINERT ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '708 E WEINERT ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '3836',
#               'postal3': 'C006'},
#   'building': {'rooms': {'bathstotal': 1.0, 'beds': 0},
#                'size': {'universalsize': 1442}},
#   'identifier': {'apn': '000000017021',
#                  'apnOrig': '17021',
#                  'attomId': 167344132,
#                  'fips': '48187',
#                  'obPropId': 16734413248187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.7,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                'latitude': '29.580135',
#                'longitude': '-97.958018'},
#   'lot': {'lotSize1': 0.5687},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000012167',
#                       'salerecdate': '2008-6-25',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2008-6-25',
#            'salesearchdate': '2008-6-25'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1951},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1710 N CAMP ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaZip',
#               'oneLine': '1710 N CAMP ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2020',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000036112',
#                  'apnOrig': '36112',
#                  'attomId': 33755868,
#                  'fips': '48187',
#                  'obPropId': 3375586848187},
#   'location': {'accuracy': 'Zip9',
#                'distance': 49.33,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123993, '
#                         'SB0000123996, ZI78155',
#                'latitude': '29.587521',
#                'longitude': '-97.965959'},
#   'lot': {'lotSize1': 0.1099},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000000661',
#                       'salerecdate': '2008-1-10',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2007-6-22',
#            'salesearchdate': '2007-6-22'},
#   'summary': {'propIndicator': '80',
#               'propLandUse': 'RESIDENTIAL ACREAGE',
#               'propclass': 'Vacant',
#               'propsubtype': 'RESIDENTIAL',
#               'proptype': 'RESIDENTIAL ACREAGE',
#               'yearbuilt': 0},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1407 MOCKINGBIRD LN',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '1407 MOCKINGBIRD LN, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '4016',
#               'postal3': 'C006'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 1566}},
#   'identifier': {'apn': '000000028633',
#                  'apnOrig': '28633',
#                  'attomId': 164888265,
#                  'fips': '48187',
#                  'obPropId': 16488826548187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.36,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'RS0001400806, SB0000123986, SB0000123989, '
#                         'SB0000123992, SB0000123993, ZI78155',
#                'latitude': '29.581445',
#                'longitude': '-97.941742'},
#   'lot': {'lotSize1': 0.2571},
#   'sale': {'amount': {'saleamt': 144375,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000023217',
#                       'salerecdate': '2018-10-10',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 48125, 'pricepersizeunit': 92},
#            'saleTransDate': '2018-10-5',
#            'salesearchdate': '2018-10-5'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1974},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '932 ANDERSON ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '932 ANDERSON ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2548',
#               'postal3': 'C009'},
#   'building': {'rooms': {'bathstotal': 1.0, 'beds': 2},
#                'size': {'universalsize': 912}},
#   'identifier': {'apn': '000000014072',
#                  'apnOrig': '14072',
#                  'attomId': 165216039,
#                  'fips': '48187',
#                  'obPropId': 16521603948187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.91,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123988, SB0000123989, '
#                         'SB0000123994, SB0000123996, ZI78155',
#                'latitude': '29.581783',
#                'longitude': '-97.977789'},
#   'lot': {'lotSize1': 0.1216},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000017628',
#                       'salerecdate': '2010-10-14',
#                       'saletranstype': 'Nominal - Non/Arms Length Sale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2010-9-13',
#            'salesearchdate': '2010-9-13'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1950},
#   'vintage': {'lastModified': '2018-1-27', 'pubDate': '2018-1-27'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '202 E PINE ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '202 E PINE ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2642',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 1742}},
#   'identifier': {'apn': '000000046967',
#                  'apnOrig': '46967',
#                  'attomId': 2158882,
#                  'fips': '48187',
#                  'obPropId': 215888248187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.67,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                'latitude': '29.582018',
#                'longitude': '-97.963976'},
#   'lot': {'lotSize1': 0.2581},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000001038',
#                       'salerecdate': '2009-11-19',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2009-11-19',
#            'salesearchdate': '2009-11-19'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1916},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '2115 LOUISE ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '2115 LOUISE ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1949',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 1.0, 'beds': 2},
#                'size': {'universalsize': 1312}},
#   'identifier': {'apn': '000000041024',
#                  'apnOrig': '41024',
#                  'attomId': 21499205,
#                  'fips': '48187',
#                  'obPropId': 2149920548187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.14,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123993, '
#                         'SB0000123996, ZI78155',
#                'latitude': '29.590610',
#                'longitude': '-97.966432'},
#   'lot': {'lotSize1': 0.1451},
#   'sale': {'amount': {'saleamt': 37500,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000005840',
#                       'salerecdate': '2019-3-19',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 18750, 'pricepersizeunit': 29},
#            'saleTransDate': '2019-3-13',
#            'salesearchdate': '2019-3-13'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1961},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '805 E CEDAR ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '805 E CEDAR ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '3814',
#               'postal3': 'C005'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 1666}},
#   'identifier': {'apn': '000000017056',
#                  'apnOrig': '17056',
#                  'attomId': 146114594,
#                  'fips': '48187',
#                  'obPropId': 14611459448187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.78,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, ZI78155',
#                'latitude': '29.578467',
#                'longitude': '-97.956433'},
#   'lot': {'lotSize1': 0.3544},
#   'sale': {'amount': {'saleamt': 151607,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000000515',
#                       'salerecdate': '2016-1-7',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 50536, 'pricepersizeunit': 91},
#            'saleTransDate': '2016-1-6',
#            'salesearchdate': '2016-1-6'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 1948},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '234 MESQUITE ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '234 MESQUITE ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '2034',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 918}},
#   'identifier': {'apn': '000000036105',
#                  'apnOrig': '36105',
#                  'attomId': 149200609,
#                  'fips': '48187',
#                  'obPropId': 14920060948187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.37,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123993, '
#                         'SB0000123996, ZI78155',
#                'latitude': '29.587299',
#                'longitude': '-97.967120'},
#   'lot': {'lotSize1': 0.1447},
#   'sale': {'amount': {'saleamt': 61089,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000003545',
#                       'salerecdate': '2010-3-5',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 67},
#            'saleTransDate': '2010-3-3',
#            'salesearchdate': '2010-3-3'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2003},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '2262 HUNTERS WAY',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '2262 HUNTERS WAY, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1771',
#               'postal3': 'R005'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 1732}},
#   'identifier': {'apn': '000000115598',
#                  'apnOrig': '115598',
#                  'attomId': 33550044,
#                  'fips': '48187',
#                  'obPropId': 3355004448187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.24,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, RS0004490658, '
#                         'SB0000123986, SB0000123989, SB0000123992, '
#                         'SB0000123993, ZI78155',
#                'latitude': '29.587933',
#                'longitude': '-97.887275'},
#   'lot': {'lotSize1': 0.505},
#   'sale': {'amount': {'saleamt': 173313,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000018789',
#                       'salerecdate': '2010-11-1',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 57771, 'pricepersizeunit': 100},
#            'saleTransDate': '2010-10-6',
#            'salesearchdate': '2010-10-6'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2005},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '610 E BAXTER ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '610 E BAXTER ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1704',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 984}},
#   'identifier': {'apn': '000000039369',
#                  'apnOrig': '39369',
#                  'attomId': 33864731,
#                  'fips': '48187',
#                  'obPropId': 3386473148187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.09,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'RS0000425046, SB0000123986, SB0000123989, '
#                         'SB0000123993, SB0000123996, ZI78155',
#                'latitude': '29.589541',
#                'longitude': '-97.958897'},
#   'lot': {'lotSize1': 0.2347},
#   'sale': {'amount': {'saleamt': 83731,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000006252',
#                       'salerecdate': '2007-3-27',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 85},
#            'saleTransDate': '2007-2-28',
#            'salesearchdate': '2007-2-28'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2006},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '532 E BAXTER ST',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '532 E BAXTER ST, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1710',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 984}},
#   'identifier': {'apn': '000000039366',
#                  'apnOrig': '39366',
#                  'attomId': 29938850,
#                  'fips': '48187',
#                  'obPropId': 2993885048187},
#   'location': {'accuracy': 'Street',
#                'distance': 49.1,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, PL4866644, RS0000425046, ZI78155',
#                'latitude': '29.589543',
#                'longitude': '-97.959568'},
#   'lot': {'lotSize1': 0.2347},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000009648',
#                       'salerecdate': '2010-6-9',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2010-5-21',
#            'salesearchdate': '2010-5-21'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2006},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '800 ROOSEVELT DR',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '800 ROOSEVELT DR, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1709',
#               'postal3': 'C017'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 1201}},
#   'identifier': {'apn': '000000045387',
#                  'apnOrig': '45387',
#                  'attomId': 167359802,
#                  'fips': '48187',
#                  'obPropId': 16735980248187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.98,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4839690, PL4866644, '
#                         'SB0000123986, SB0000123989, SB0000123993, '
#                         'SB0000123996, ZI78155',
#                'latitude': '29.590597',
#                'longitude': '-97.956596'},
#   'lot': {'lotSize1': 0.2541},
#   'sale': {'amount': {'saleamt': 142500,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000021743',
#                       'salerecdate': '2015-10-21',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 47500, 'pricepersizeunit': 119},
#            'saleTransDate': '2015-10-20',
#            'salesearchdate': '2015-10-20'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2000},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '515 MILLS WAY',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '515 MILLS WAY, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '1873',
#               'postal3': 'R001'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000033833',
#                  'apnOrig': '33833',
#                  'attomId': 206998896,
#                  'fips': '48187',
#                  'obPropId': 20699889648187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.1,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, RS0000369307, ZI78155',
#                'latitude': '29.591156',
#                'longitude': '-97.894111'},
#   'lot': {'lotSize1': 10.003},
#   'sale': {'amount': {'saleamt': 77500,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000007534',
#                       'salerecdate': '2016-4-13',
# ...
#   'location': {'accuracy': 'Street',
#                'distance': 47.71,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, DB4832370, MT30002734, PL4850820, '
#                         'RS0001401301, SB0000122843, SB0000122844, '
#                         'SB0000122850, SB0000136121, ZI78130',
#                'latitude': '29.658901',
#                'longitude': '-98.102314'},
#   'lot': {'lotSize1': 0.1791},
#   'sale': {'amount': {'saleamt': 146256,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000020860',
#                       'salerecdate': '2008-11-10',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 48752, 'pricepersizeunit': 81},
#            'saleTransDate': '2008-10-30',
#            'salesearchdate': '2008-10-30'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2008},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '4006 LEGEND POND',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaExt',
#               'oneLine': '4006 LEGEND POND, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '2040',
#               'postal3': 'R028'},
#   'building': {'rooms': {'bathstotal': 3.0, 'beds': 4},
#                'size': {'universalsize': 2402}},
#   'identifier': {'apn': '000000154646',
#                  'apnOrig': '154646',
#                  'attomId': 252025091,
#                  'fips': '48187',
#                  'obPropId': 25202509148187},
#   'location': {'accuracy': 'Extrapolate',
#                'distance': 49.01,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, MT30002734, PL4850820, '
#                         'SB0000119355, SB0000119356, SB0000119372, ZI78130',
#                'latitude': '29.642889',
#                'longitude': '-98.113894'},
#   'lot': {'lotSize1': 0.1254},
#   'sale': {'amount': {'saleamt': 225946,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000012602',
#                       'salerecdate': '2016-6-14',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 94},
#            'saleTransDate': '2016-5-19',
#            'salesearchdate': '2016-5-19'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2016},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '120 TONTO TRL',
#               'line2': 'SEGUIN, TX 78155',
#               'locality': 'Seguin',
#               'matchCode': 'ExaStr',
#               'oneLine': '120 TONTO TRL, SEGUIN, TX 78155',
#               'postal1': '78155',
#               'postal2': '0349',
#               'postal3': 'R007'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 1568}},
#   'identifier': {'apn': '000000024470',
#                  'apnOrig': '24470',
#                  'attomId': 10042533,
#                  'fips': '48187',
#                  'obPropId': 1004253348187},
#   'location': {'accuracy': 'Street',
#                'distance': 44.58,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4832160, PL4829384, '
#                         'RS0000398289, SB0000122824, SB0000122825, '
#                         'SB0000122826, SB0000122827, ZI78155',
#                'latitude': '29.653779',
#                'longitude': '-97.944013'},
#   'lot': {'lotSize1': 0.519},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000009641',
#                       'salerecdate': '2008-5-22',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2008-5-20',
#            'salesearchdate': '2008-5-20'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'MOBILE HOME',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'MOBILE HOME',
#               'proptype': 'MOBILE HOME',
#               'yearbuilt': 2004},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '2579 PAHMEYER RD',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaStr',
#               'oneLine': '2579 PAHMEYER RD, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '3933',
#               'postal3': 'R044'},
#   'building': {'rooms': {'bathstotal': 2.0, 'beds': 3},
#                'size': {'universalsize': 2738}},
#   'identifier': {'apn': '000000163694',
#                  'apnOrig': '163694',
#                  'attomId': 155233318,
#                  'fips': '48187',
#                  'obPropId': 15523331848187},
#   'location': {'accuracy': 'Street',
#                'distance': 48.39,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, DB4832370, MT30002734, PL4850820, '
#                         'RS0000409229, SB0000122843, SB0000122844, '
#                         'SB0000122850, SB0000136121, ZI78130',
#                'latitude': '29.654160',
#                'longitude': '-98.116624'},
#   'lot': {'lotSize1': 0.1942},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000004853',
#                       'salerecdate': '2019-3-6',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2019-1-1',
#            'salesearchdate': '2019-1-1'},
#   'summary': {'propIndicator': '21',
#               'propLandUse': 'DUPLEX',
#               'propclass': '"Duplex, Triplex, Quadplex)"',
#               'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#               'proptype': 'DUPLEX',
#               'yearbuilt': 2017},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '191 MARUNGO LN',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaStr',
#               'oneLine': '191 MARUNGO LN, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '8265',
#               'postal3': 'R030'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 4058}},
#   'identifier': {'apn': '000000128378',
#                  'apnOrig': '128378',
#                  'attomId': 165423690,
#                  'fips': '48187',
#                  'obPropId': 16542369048187},
#   'location': {'accuracy': 'Street',
#                'distance': 47.31,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, DB4832370, MT30002734, '
#                         'RS0000376033, SB0000122843, SB0000122844, '
#                         'SB0000122850, SB0000136121, ZI78130',
#                'latitude': '29.654636',
#                'longitude': '-98.076980'},
#   'lot': {'lotSize1': 1.84},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000005378',
#                       'salerecdate': '2007-3-13',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2007-3-12',
#            'salesearchdate': '2007-3-12'},
#   'summary': {'propIndicator': '21',
#               'propLandUse': 'DUPLEX',
#               'propclass': '"Duplex, Triplex, Quadplex)"',
#               'propsubtype': 'MISCELLANEOUS INDUSTRIAL',
#               'proptype': 'DUPLEX',
#               'yearbuilt': 2007},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '1115 KRAUSE LN',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaStr',
#               'oneLine': '1115 KRAUSE LN, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '1908',
#               'postal3': 'R032'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 924}},
#   'identifier': {'apn': '000000055410',
#                  'apnOrig': '55410',
#                  'attomId': 164909359,
#                  'fips': '48187',
#                  'obPropId': 16490935948187},
#   'location': {'accuracy': 'Street',
#                'distance': 46.43,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893500, DB4814730, SB0000119355, '
#                         'SB0000119356, SB0000119372, ZI78130',
#                'latitude': '29.655023',
#                'longitude': '-98.041868'},
#   'lot': {'lotSize1': 2.0},
#   'sale': {'amount': {'saleamt': 0,
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000006998',
#                       'salerecdate': '2012-4-13',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2012-4-13',
#            'salesearchdate': '2012-4-13'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'MOBILE HOME',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'MOBILE HOME',
#               'proptype': 'MOBILE HOME',
#               'yearbuilt': 1982},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '115 RUGER PATH',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaStr',
#               'oneLine': '115 RUGER PATH, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '3959',
#               'postal3': 'R028'},
#   'building': {'rooms': {'bathstotal': 4.0, 'beds': 4},
#                'size': {'universalsize': 2844}},
#   'identifier': {'apn': '000000131372',
#                  'apnOrig': '131372',
#                  'attomId': 219318432,
#                  'fips': '48187',
#                  'obPropId': 21931843248187},
#   'location': {'accuracy': 'Street',
#                'distance': 47.52,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, MT30002734, PL4850820, '
#                         'RS0000096629, ZI78130',
#                'latitude': '29.660535',
#                'longitude': '-98.098821'},
#   'lot': {'lotSize1': 0.1515},
#   'sale': {'amount': {'saleamt': 221108,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000021428',
#                       'salerecdate': '2013-10-2',
#                       'saletranstype': 'New Construction'},
#            'calculation': {'priceperbed': 55277, 'pricepersizeunit': 78},
#            'saleTransDate': '2013-9-30',
#            'salesearchdate': '2013-9-30'},
#   'summary': {'propIndicator': '10',
#               'propLandUse': 'SFR',
#               'propclass': 'Single Family Residence / Townhouse',
#               'propsubtype': 'HOUSE',
#               'proptype': 'SFR',
#               'yearbuilt': 2013},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '328 RIVER PARK DR',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaZip',
#               'oneLine': '328 RIVER PARK DR, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '3569',
#               'postal3': 'R037'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000127630',
#                  'apnOrig': '127630',
#                  'attomId': 146063788,
#                  'fips': '48187',
#                  'obPropId': 14606378848187},
#   'location': {'accuracy': 'Zip9',
#                'distance': 47.11,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, DB4832370, MT30002734, '
#                         'SB0000122843, SB0000122844, SB0000122850, '
#                         'SB0000136121, ZI78130',
#                'latitude': '29.656185',
#                'longitude': '-98.072729'},
#   'lot': {'lotSize1': 0.545},
#   'sale': {'amount': {'saleamt': 62500,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000011326',
#                       'salerecdate': '2018-5-29',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2018-5-23',
#            'salesearchdate': '2018-5-23'},
#   'summary': {'propIndicator': '80',
#               'propLandUse': 'RESIDENTIAL ACREAGE',
#               'propclass': 'Vacant',
#               'propsubtype': 'RESIDENTIAL',
#               'proptype': 'RESIDENTIAL ACREAGE',
#               'yearbuilt': 0},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}},
#  {'address': {'country': 'US',
#               'countrySubd': 'TX',
#               'line1': '368 RIVER PARK DR',
#               'line2': 'NEW BRAUNFELS, TX 78130',
#               'locality': 'New Braunfels',
#               'matchCode': 'ExaZip',
#               'oneLine': '368 RIVER PARK DR, NEW BRAUNFELS, TX 78130',
#               'postal1': '78130',
#               'postal2': '3569',
#               'postal3': 'R037'},
#   'building': {'rooms': {'bathstotal': 0.0, 'beds': 0},
#                'size': {'universalsize': 0}},
#   'identifier': {'apn': '000000127635',
#                  'apnOrig': '127635',
#                  'attomId': 167700072,
#                  'fips': '48187',
#                  'obPropId': 16770007248187},
#   'location': {'accuracy': 'Zip9',
#                'distance': 47.11,
#                'elevation': 0.0,
#                'geoid': 'CO48187, CS4893470, DB4832370, MT30002734, '
#                         'SB0000122843, SB0000122844, SB0000122850, '
#                         'SB0000136121, ZI78130',
#                'latitude': '29.656185',
#                'longitude': '-98.072729'},
#   'lot': {'lotSize1': 0.546},
#   'sale': {'amount': {'saleamt': 49000,
#                       'salecode': 'Estimated Sale Price',
#                       'saledisclosuretype': 2,
#                       'saledocnum': '0000019196',
#                       'salerecdate': '2014-10-30',
#                       'saletranstype': 'Resale'},
#            'calculation': {'priceperbed': 0, 'pricepersizeunit': 0},
#            'saleTransDate': '2014-10-27',
#            'salesearchdate': '2014-10-27'},
#   'summary': {'propIndicator': '80',
#               'propLandUse': 'RESIDENTIAL ACREAGE',
#               'propclass': 'Vacant',
#               'propsubtype': 'RESIDENTIAL',
#               'proptype': 'RESIDENTIAL ACREAGE',
#               'yearbuilt': 0},
#   'vintage': {'lastModified': '2019-11-11', 'pubDate': '2019-11-11'}}]

# %% [markdown]
# # Census API
# ---------

# %%
censusURL = 'https://api.census.gov/data.json'
censusResponse = requests.get(censusURL)
pp.pprint(censusResponse.json())
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@id': 'https://api.census.gov/data/1986/cbp.json',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'dataset': [{'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1986/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1986/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1986/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1986/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1986/cbp/variables.json',
#               'c_vintage': 1986,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1986/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1986',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1986/1986',
#               'title': '1986 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['zbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1994/zbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1994/zbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1994/zbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1994/zbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1994/zbp/variables.json',
#               'c_vintage': 1994,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'ZIP Code Business Patterns (ZBP) is an annual '
#                              'series that provides economic data by ZIP Code.  '
#                              'This table includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll for All Industries by 5-digit ZIP Code.  '
#                              'All Industries is set using SIC=00 from 1994 to '
#                              '1997 and then with NAICS=00 from 1998 to '
#                              'present.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1994/zbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/ZBPTotal1994',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2017-05-23',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1994/1994',
#               'title': '1994 County Business Patterns - Zip Code Business '
#                        'Patterns: Total For Zip Code'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1987/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1987/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1987/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1987/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1987/cbp/variables.json',
#               'c_vintage': 1987,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1987/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1987',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1987/1987',
#               'title': '1987 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1995/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1995/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1995/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1995/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1995/cbp/variables.json',
#               'c_vintage': 1995,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1995/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1995',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1995/1995',
#               'title': '1995 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1988/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1988/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1988/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1988/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1988/cbp/variables.json',
#               'c_vintage': 1988,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1988/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1988',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1988/1988',
#               'title': '1988 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1989/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1989/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1989/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1989/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1989/cbp/variables.json',
#               'c_vintage': 1989,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1989/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1989',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1989/1989',
#               'title': '1989 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['zbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1995/zbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1995/zbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1995/zbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1995/zbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1995/zbp/variables.json',
#               'c_vintage': 1995,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'ZIP Code Business Patterns (ZBP) is an annual '
#                              'series that provides economic data by ZIP Code.  '
#                              'This table includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll for All Industries by 5-digit ZIP Code.  '
#                              'All Industries is set using SIC=00 from 1994 to '
#                              '1997 and then with NAICS=00 from 1998 to '
#                              'present.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1995/zbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/ZBPTotal1995',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2017-05-23',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1995/1995',
#               'title': '1995 County Business Patterns - Zip Code Business '
#                        'Patterns: Total For Zip Code'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1990/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1990/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1990/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1990/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1990/cbp/variables.json',
#               'c_vintage': 1990,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides economic data by industry '
#                              'at the U.S., State, County and Metropolitan Area '
#                              'levels. This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. CBP provides statistics for businesses '
#                              'with paid employees for the U.S., Puerto Rico, '
#                              'and the Island Areas. Census Bureau staff '
#                              'identified a processing error that affects '
#                              'selected data from the 2014 County Business '
#                              'Patterns (CBP). As a result, we suppressed 2014 '
#                              'employment and payroll totals in the Health Care '
#                              'and Social Assistance sector (Sector 62) for the '
#                              'following geographies: U.S.; Michigan; Battle '
#                              'Creek, MI metro area; Calhoun County, MI; and '
#                              'the 3rd congressional district of Michigan. This '
#                              'processing error did not affect other sectors. '
#                              'While suppressed values can be derived by '
#                              'subtraction, we do not recommend using the '
#                              'derived values in any analyses.  The Census '
#                              'Bureau plans to release revised statistics at a '
#                              'later date.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1990/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/CBP1990',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-02-13',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1990/1990',
#               'title': '1990 County Business Patterns: Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['pep', 'int_charagegroups'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1990/pep/int_charagegroups/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1990/pep/int_charagegroups/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1990/pep/int_charagegroups/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/1990/pep/int_charagegroups/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1990/pep/int_charagegroups/variables.json',
#               'c_vintage': 1990,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'pop.population.estimates@census.gov'},
#               'description': 'Intercensal Estimates of the Resident Population '
#                              'by Age Groups, Race by Sex, and Hispanic Origin '
#                              'for Counties: July 1, 1990 to July 1, 1999 // '
#                              'Source: U.S. Census Bureau, Population Division '
#                              '// For detailed information about the methods '
#                              'used to create the intercensal population '
#                              'estimates, see '
#                              'https://www.census.gov/popest/methodology/intercensal_nat_meth.pdf. '
#                              "// The Census Bureau's Population Estimates "
#                              'Program produces intercensal estimates each '
#                              'decade by adjusting the existing time series of '
#                              'postcensal estimates for a decade to smooth the '
#                              'transition from one decennial census count to '
#                              'the next. They differ from the postcensal '
#                              'estimates that are released annually because '
#                              'they rely on a formula that redistributes the '
#                              'difference between the April 1 postcensal '
#                              'estimate and April 1 census count for the end of '
#                              'the decade across the estimates for that decade. '
#                              'Meanwhile, the postcensal estimates incorporate '
#                              'current data on births, deaths, and migration to '
#                              'produce each new vintage of estimates, and to '
#                              'revise estimates for years back to the last '
#                              'census. The Population Estimates Program '
#                              'provides additional information including '
#                              'historical and postcensal estimates, evaluation '
#                              'estimates, demographic analysis, and research '
#                              'papers on its website: '
#                              'https://www.census.gov/popest/index.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1990/pep/int_charagegroups',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/POPESTintercensalcharagegroups1990',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2016-09-13',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': 'April 1,2010',
#               'title': '1990 Population Estimates - 1990-2000 Intercensal '
#                        'Estimates: County Estimates by 5 Year Age Groups, Race '
#                        'by Sex, and Hispanic Origin'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['zbp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1997/zbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1997/zbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1997/zbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/1997/zbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1997/zbp/variables.json',
#               'c_vintage': 1997,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'ewd.county.business.patterns@census.gov'},
#               'description': 'ZIP Code Business Patterns (ZBP) is an annual '
#                              'series that provides economic data by ZIP Code.  '
#                              'This table includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll for All Industries by 5-digit ZIP Code.  '
#                              'All Industries is set using SIC=00 from 1994 to '
#                              '1997 and then with NAICS=00 from 1998 to '
#                              'present.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1997/zbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/ZBPTotal1997',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2017-05-23',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '1997/1997',
#               'title': '1997 County Business Patterns - Zip Code Business '
#                        'Patterns: Total For Zip Code'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['pep', 'int_natcivpop'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1990/pep/int_natcivpop/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1990/pep/int_natcivpop/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1990/pep/int_natcivpop/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/1990/pep/int_natcivpop/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1990/pep/int_natcivpop/variables.json',
#               'c_vintage': 1990,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'pop.population.estimates@census.gov'},
#               'description': 'Monthly Intercensal Estimates of the Civilian '
#                              'Population by Single Year of Age and Sex: April '
#                              '1, 1990 to April 1, 2000 // Source: U.S. Census '
#                              'Bureau, Population Division // For detailed '
#                              'information about the methods used to create the '
#                              'intercensal population estimates, see '
#                              'https://www.census.gov/popest/methodology/intercensal_nat_meth.pdf. '
#                              "// The Census Bureau's Population Estimates "
#                              'Program produces intercensal estimates each '
#                              'decade by adjusting the existing time series of '
#                              'postcensal estimates for a decade to smooth the '
#                              'transition from one decennial census count to '
#                              'the next. They differ from the postcensal '
#                              'estimates that are released annually because '
#                              'they rely on a formula that redistributes the '
#                              'difference between the April 1 postcensal '
#                              'estimate and April 1 census count for the end of '
#                              'the decade across the estimates for that decade. '
#                              'Meanwhile, the postcensal estimates incorporate '
#                              'current data on births, deaths, and migration to '
#                              'produce each new vintage of estimates, and to '
#                              'revise estimates for years back to the last '
#                              'census. The Population Estimates Program '
#                              'provides additional information including '
#                              'historical and postcensal estimates, evaluation '
#                              'estimates, demographic analysis, and research '
#                              'papers on its website: '
#                              'https://www.census.gov/popest/index.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/1990/pep/int_natcivpop',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/POPESTintercensalnatcivpop1990',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2016-09-13',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': 'April 1,2010',
#               'title': '1990 Population Estimates - 1990-2000 Intercensal '
#                        'Estimates: United States Civilian Population Estimates '
#                        'by Age and Sex'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['pep', 'int_natresafo'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/1990/pep/int_natresafo/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/1990/pep/int_natresafo/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/1990/pep/int_natresafo/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/1990/pep/int_natresafo/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/1990/pep/int_natresafo/variables.json',
#               'c_vintage': 1990,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'pop.population.estimates@census.gov'},
#               'description': 'Monthly Intercensal Estimates of the Resident '
#                              'plus Armed Forces Overseas Population by Single '
#                              'Year of Age and Sex: April 1, 1990 to April 1, '
#                              '2000 // Source: U.S. Census Bureau, Population '
#                              'Division // For detailed information about the '
#                              'methods used to create the intercensal '
#                              'population estimates, see '
#                              'https://www.census.gov/popest/methodology/intercensal_nat_meth.pdf. '
#                              "// The Census Bureau's Population Estimates "
#                              'Program produces intercensal estimates each '
#                              'decade by adjusting the existing time series of '
#                              'postcensal estimates for a decade to smooth the '
#                              'transition from one decennial census count to '
#                              'the next. They differ from the postcensal '
#                              'estimates that are released annually because '
#                              'they rely on a formula that redistributes the '
#                              'difference between the April 1 postcensal '
#                              'estimate and April 1 census count for the end of '
#                              'the decade across the estimates for that decade. '
#                              'Meanwhile, the postcensal estimates incorporate '
#                              'current data on births, deaths, and migration to '
#                              'produce each new vintage of estimates, and to '
#                              'revise estimates for years back to the last '
#                              'census. The Population Estimates Program '
#                              'provides additional information including '
#                              'historical and postcensal estimates, evaluation '
#                              'estimates, demographic analysis, and research '
#                              'papers on its website: '
#                              'https://www.census.gov/popest/index.html.',
# ...
#               'temporal': 'unidentified',
#               'title': 'Economic Census: Economic Census of the United States: '
#                        'Commodity Flow Survey Hazmat Data'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['cfsprelim'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2012/cfsprelim/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2012/cfsprelim/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2012/cfsprelim/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_tagsLink': 'https://api.census.gov/data/2012/cfsprelim/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2012/cfsprelim/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2012/cfsprelim/variables.json',
#               'c_vintage': 2012,
#               'contactPoint': {'fn': 'Data User Outreach',
#                                'hasEmail': 'mailto:ewd.outreach@census.gov'},
#               'description': 'The 2012 Commodity Flow Survey (CFS) is '
#                              'undertaken through a partnership between the '
#                              'U.S. Census Bureau, U.S. Department of Commerce, '
#                              'and the Research and Innovation Technology '
#                              'Administration, Bureau of Transportation '
#                              'Statistics (BTS), U.S. Department of '
#                              'Transportation. This survey produces data on the '
#                              'movement of goods in the United States. It '
#                              'provides information on commodities shipped, '
#                              'their value, weight, and mode of transportation, '
#                              'as well as the origin and destination of '
#                              'shipments of manufacturing, mining, wholesale, '
#                              'and select retail and services establishments. '
#                              'The data from the CFS are used by public policy '
#                              'analysts and for transportation planning and '
#                              'decision making to access the demand for '
#                              'transportation facilities and services, energy '
#                              'use, and safety risk and environmental concerns. '
#                              'This dataset provides data for the Preliminary '
#                              'Report.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2012/cfsprelim',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/CFSPRELIM2012',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-11-18 16:03:28.0',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Economic Census: Economic Census of the United States: '
#                        'Commodity Flow Survey Preliminary Data'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['cbp'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2017/cbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2017/cbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2017/cbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_tagsLink': 'https://api.census.gov/data/2017/cbp/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2017/cbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2017/cbp/variables.json',
#               'c_vintage': 2017,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'mailto:Econ.dissemination@census.gov'},
#               'description': 'County Business Patterns (CBP) is an annual '
#                              'series that provides sub-national economic data '
#                              'by industry.  This series includes the number of '
#                              'establishments, employment during the week of '
#                              'March 12, first quarter payroll, and annual '
#                              'payroll. This data is useful for studying the '
#                              'economic activity of small areas, analyzing '
#                              'economic changes over time, and as a benchmark '
#                              'for other statistical series, surveys, and '
#                              'databases between economic censuses. Businesses '
#                              'use the data for analyzing market potential, '
#                              'measuring the effectiveness of sales and '
#                              'advertising programs, setting sales quotas, and '
#                              'developing budgets. Government agencies use the '
#                              'data for administration and planning.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2017/cbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/CBP2017',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-11-07 14:49:23.0',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Economic Annual Surveys: Business Patterns: County '
#                        'Business Patterns'},
#              {'@type': 'dcat:Dataset',
#               'c.is_cell_limit_discovery': True,
#               'c_dataset': ['zbp'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2017/zbp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2017/zbp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2017/zbp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_tagsLink': 'https://api.census.gov/data/2017/zbp/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2017/zbp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2017/zbp/variables.json',
#               'c_vintage': 2017,
#               'contactPoint': {'fn': 'CBP Staff',
#                                'hasEmail': 'mailto:Econ.dissemination@census.gov'},
#               'description': 'ZIP Code Business Patterns Methodology: Basis of '
#                              'Reporting ZIP Code Business Patterns is '
#                              'tabulated at the establishment level. An '
#                              'establishment is a single physical location at '
#                              'which business is conducted or services or '
#                              'industrial operations are performed. It is not '
#                              'necessarily identical with a company or '
#                              'enterprise, which may consist of one or more '
#                              'establishments. When two or more activities are '
#                              'carried on at a single location under a single '
#                              'ownership, all activities generally are grouped '
#                              'together as a single establishment. The entire '
#                              'establishment is classified on the basis of its '
#                              'major activity and all data are included in that '
#                              'classification. Establishment-size designations '
#                              'are determined by paid employment in the '
#                              'mid-March pay period. The size group "1 to 4" '
#                              'includes establishments that did not report any '
#                              'paid employees in the mid-March pay period but '
#                              'paid wages to at least one employee at some time '
#                              'during the year. Establishment counts represent '
#                              'the number of locations with paid employees any '
#                              'time during the year. Sources of the Data '
#                              'Payroll and employment data are tabulated from '
#                              'administrative records for single-unit firms and '
#                              'a combination of administrative records and '
#                              'survey-collected data for multi-unit firms. Read '
#                              'more >> Geographic Area Coding Most geography '
#                              'codes are derived from the physical location '
#                              'address reported in Census Bureau programs. The '
#                              'Internal Revenue Service and the Bureau of Labor '
#                              'Statistics provide supplemental address '
#                              'information. Reliability of Data The data are '
#                              'not subject to sampling error, but are subject '
#                              'to nonsampling errors, which can be attributed '
#                              'to several sources: inability to identify all '
#                              'cases that should be in the universe; definition '
#                              'and classification difficulties; errors in '
#                              'recording or coding the data obtained; and other '
#                              'errors of coverage, processing, and estimation '
#                              'for missing or misreported data. Read more >> '
#                              'Dollar Values All dollar values presented in the '
#                              'reports from the ZIP Code Business Patterns are '
#                              'expressed in current dollars, i.e, 2009 data are '
#                              'expressed in 2009 dollars and 2008 data in 2008 '
#                              'dollars. Consequently, when making comparisons '
#                              'to prior years, data users should take into '
#                              'consideration the inflation that has occurred. '
#                              'All dollar values, unless noted otherwise, are '
#                              'shown in thousands of dollars. Disclosure In '
#                              'accordance with federal law (U.S. Code, Title '
#                              '13, Section 9) no data are published that would '
#                              'disclose the operations of an individual '
#                              'establishment or business. Noise Infusion: ZIP '
#                              'Code Business Patterns apply the Noise Infusion '
#                              'method of data protection. Noise infusion is a '
#                              'method used to protect data in which values for '
#                              'each establishment such as first-quarter '
#                              'payroll, annual payroll, and number of employees '
#                              'are perturbed prior to publication by applying a '
#                              'random noise multiplier to the data for each '
#                              'company. This method results in a relatively '
#                              'small change to the vast majority of cell '
#                              'values. Read more >> The number of '
#                              'establishments in a particular tabulation cell '
#                              'is not considered a disclosure; therefore, this '
#                              'information may be released without the addition '
#                              'of protective noise. Other Survey-Specific '
#                              'Information Definitional and coverage '
#                              'differences may affect the direct comparison of '
#                              'Economic Census and ZIP Code Business Patterns '
#                              'data. Read more >>',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2017/zbp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/ZBP2017',
#               'keyword': ['employment'],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-12-05 14:23:04.0',
#               'programCode': ['006:007'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Economic Annual Surveys: Business Patterns: Zipcode '
#                        'Business Patterns',
#               'variable_cell_limit': '5000000'}],
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'}

# %%
for i in censusResponse.json()
